# %% [markdown]
# # Instrucciones
#
# * Enviar a johnathancalle@gmail.com antes de las 9:50 a.m.
# * Todos los puntos valen lo mismo.
# * Cada punto debe resolverse usando Greedy o BackTracking.
# * Calcule la complejidad temporal y espacial de cada solución propuesta.
# * Todas las soluciones están sujetas a sustentación.
# * Cualquier intento de fraude anulará el examen.

# %% [markdown]
# # 🧩 **Ejercicio 1**

# %% [markdown]
# ---
#
#
#
# ### 💬 **Descripción**
#
# Se te da una cadena `s`.
# Puedes transformar **cada letra** de forma individual a **mayúscula o minúscula** para crear nuevas combinaciones.
#
# Además, para **cada dígito** de la cadena se aplican las siguientes reglas:
#
# * Si el dígito es **par**, reemplázalo por su **cuadrado**.
# * Si el dígito es **impar**, **déjalo igual**.
#
# Debes retornar **todas las posibles cadenas** que se pueden generar aplicando estas transformaciones.
# El resultado puede presentarse en cualquier orden.
#
# ---
#
# ### 🧩 **Ejemplo 1**
#
# **Entrada:**
#
# ```
# s = "a1b2"
# ```
#
# **Salida:**
#
# ```
# ["a1b4", "a1B4", "A1b4", "A1B4"]
# ```
#
# **Explicación:**
#
# * Las letras `'a'` y `'b'` pueden cambiar a mayúscula o minúscula.
# * El dígito `'1'` es impar → se mantiene igual.
# * El dígito `'2'` es par → se eleva al cuadrado (`2² = 4`).
#
# ---
#
# ### 🧩 **Ejemplo 2**
#
# **Entrada:**
#
# ```
# s = "3z4"
# ```
#
# **Salida:**
#
# ```
# ["3z16", "3Z16"]
# ```
#
# **Explicación:**
#
# * La letra `'z'` puede ser `'z'` o `'Z'`.
# * El dígito `'3'` es impar → se mantiene.
# * El dígito `'4'` es par → se transforma en `'16'`.
#
# ---
#
# ### ⚙️ **Restricciones**
#
# * 1 ≤ `s.length` ≤ 12
# * `s` puede contener letras minúsculas, letras mayúsculas y dígitos (`0-9`).
# * El orden de salida no es relevante.

# %%
def e1():
  ...

# %% [markdown]
# # ⛽ **Ejercicio 2**

# %% [markdown]
# ---
#
#
#
# ### 💬 **Descripción**
#
# Un coche viaja desde una posición inicial hasta un destino que se encuentra a una distancia de `target` millas al este del punto de partida.
#
# A lo largo del camino hay **estaciones de gasolina**, representadas mediante un arreglo `stations`, donde
# `stations[i] = [posiciónᵢ, combustibleᵢ]` indica que:
#
# * La estación `i` está ubicada a `posiciónᵢ` millas del punto de partida.
# * La estación `i` dispone de `combustibleᵢ` litros de gasolina.
#
# El coche tiene un **tanque con capacidad infinita**, pero **inicia con `startFuel` litros**.
# Consume **1 litro de gasolina por cada milla recorrida**.
#
# Cuando el coche llega a una estación, **puede decidir repostar**, tomando **todo el combustible disponible en esa estación**.
#
# Tu tarea es determinar el **mínimo número de paradas necesarias** para llegar al destino.
#
# Si el coche **no puede llegar al destino**, debes retornar `-1`.
#
# > 💡 Nota:
# >
# > * Si el coche llega a una estación con 0 litros restantes, aún puede repostar.
# > * Si llega al destino con 0 litros, también se considera que alcanzó su objetivo.
#
# ---
#
# ### 🧩 **Ejemplo 1**
#
# **Entrada:**
#
# ```
# target = 1
# startFuel = 1
# stations = []
# ```
#
# **Salida:**
#
# ```
# 0
# ```
#
# **Explicación:**
# Puede llegar al destino sin detenerse a repostar.
#
# ---
#
# ### 🧩 **Ejemplo 2**
#
# **Entrada:**
#
# ```
# target = 100
# startFuel = 1
# stations = [[10,100]]
# ```
#
# **Salida:**
#
# ```
# -1
# ```
#
# **Explicación:**
# No alcanza ni siquiera la primera estación con el combustible inicial.
#
# ---
#
# ### 🧩 **Ejemplo 3**
#
# **Entrada:**
#
# ```
# target = 100
# startFuel = 10
# stations = [[10,60],[20,30],[30,30],[60,40]]
# ```
#
# **Salida:**
#
# ```
# 2
# ```
#
# **Explicación:**
#
# * El coche inicia con 10 litros.
# * Conduce hasta la posición 10 (consume 10 litros) y reposta +60 litros.
# * Avanza hasta la posición 60 (consume 50 litros) y reposta +40 litros.
# * Finalmente llega al destino con combustible suficiente.
#   → En total realizó **2 paradas**.
#
# ---
#
# ### ⚙️ **Restricciones**
#
# * 1 ≤ `target`, `startFuel` ≤ 10⁹
# * 0 ≤ `stations.length` ≤ 500
# * 1 ≤ `posiciónᵢ` < `posiciónᵢ₊₁` < `target`
# * 1 ≤ `combustibleᵢ` < 10⁹
#
# ---
#
# ### 💡 **Indicaciones**
#
# * La complejidad esperada es **O(n log n)**. (Justifique la complejidad alcanzada por su solución).

# %%
def e2():
  ...

# %% [markdown]
# # 🧩 **Ejercicio 3**

# %% [markdown]
# ### 💬 **Descripción**
# Se desea encontrar **todas las combinaciones posibles de `k` números distintos** que sumen exactamente `n`, cumpliendo las siguientes condiciones:
#
# 1. Solo se pueden usar **números del 1 al 9**.
# 2. Cada número se puede utilizar **como máximo una vez**.
# 3. No se deben repetir combinaciones (es decir, [1,2,4] y [2,1,4] cuentan como la misma combinación).
# 4. El orden de las combinaciones en el resultado **no importa**.
#
# El objetivo es devolver **una lista con todas las combinaciones válidas**. Si no existe ninguna combinación que cumpla las condiciones, se debe devolver una lista vacía `[]`.
#
# ---
#
# ### 🔢 **Ejemplos**
#
# #### Ejemplo 1
#
# **Entrada:**
#
# ```text
# k = 3, n = 7
# ```
#
# **Salida:**
#
# ```text
# [[1,2,4]]
# ```
#
# **Explicación:**
# La única combinación posible que suma 7 usando tres números distintos entre 1 y 9 es `[1, 2, 4]`.
#
# ---
#
# #### Ejemplo 2
#
# **Entrada:**
#
# ```text
# k = 4, n = 25
# ```
#
# **Salida:**
#
# ```text
# [[1, 7, 8, 9], [2, 6, 8, 9], [3, 5, 8, 9], [3, 6, 7, 9], [4, 5, 7, 9], [4, 6, 7, 8]]
# ```
#
# ---
#
# #### Ejemplo 3
#
# **Entrada:**
#
# ```text
# k = 9, n = 45
# ```
#
# **Salida:**
#
# ```text
# [[1, 2, 3, 4, 5, 6, 7, 8, 9]]
# ```
#
#
# ---
#
# ### ⚙️ **Restricciones**
#
# * 2 ≤ k ≤ 9
# * 1 ≤ n ≤ 60
#
# ---

# %%
def e3():
  ...
