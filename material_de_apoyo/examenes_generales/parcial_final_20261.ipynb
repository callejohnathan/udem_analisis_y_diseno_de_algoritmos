# %% [markdown]
# # Instrucciones Generales
# ---
#
# - El uso de **type hints** es obligatorio en todas las funciones.
# - Cada punto debe incluir un análisis de **complejidad temporal y espacial** justificado.
# - El examen está sujeto a **sustentación oral**. Cualquier estudiante puede ser citado a defender su solución.
# - Cualquier intento de **fraude** anulará automáticamente el examen de los implicados.
# - **No se permite el uso de librerías externas**, salvo aquellas necesarias para implementar estructuras de tipo *heap* (por ejemplo, `heapq`).
# - Cada punto incluye casos de prueba orientativos. **Pasar los casos de prueba no garantiza una solución correcta**: pueden existir casos límite no contemplados. Es responsabilidad del estudiante validar su solución de forma exhaustiva.
# - Elimine todos los prints y código comentado de su solución para el envío.

# %% [markdown]
# # Ejercicios
# ---
# * Usted deberá elegir 3 de los 4 propuestos. Todos los puntos tienen el mismo peso.

# %% [markdown]
# ## Ejercicio 1 — Auditoría Lingüística
# ---

# %% [markdown]
# Una empresa de análisis forense digital ha desarrollado una herramienta para detectar
# patrones de comunicación encubierta en mensajes de texto. El sistema sospecha que ciertos mensajes contienen palabras clave ocultas como anagramas: reordenaciones de una palabra objetivo dentro del cuerpo del mensaje.
#
# Dado un string `s1` (el mensaje) y un string `s2` (la palabra objetivo), implemente una
# función que retorne cuántos substrings de `s1` son anagramas de `s2`. Tenga en cuenta que ambos strings pueden contener caracteres repetidos.
#
# Se espera una solución con complejidad temporal máxima de **O(n·k)**, siendo `n = len(s1)` y `k = len(s2)`. Deberá justificar tanto la complejidad temporal como la espacial alcanzada.
#
# **Restricción:** no se permite el uso de `Counter`, `sorted`, ni ninguna utilidad de
# librería estándar que resuelva el problema de forma directa.
#
#
#
# #### Ejemplo 1
# * s1 = "cbaebabacd"
# * s2 = "abc"
# * Substrings anagramas: "cba" (índice 0–2), "bac" (índice 6–8)
#
# #### Ejemplo 2
# * s1 = "abab"
# * s2 = "ab"
# * Substrings anagramas: "ab" (0–1), "ba" (1–2), "ab" (2–3)

# %% [markdown]
# ---
# * Casos de prueba

# %%
'''
- Recuerde incluir typehints y justificación del análisis de complejidad temporal y espacial
- Si usa programación dinámica, describa qué significa cada subproblema, es decir, su clave:valor en memo o la celda de la tabla de programación dinámica.
- Puede borrar este comentario si lo considera necesario
'''

# su función aquí

# %%
# recuerde cambiar el XXX por el nombre de su función incluyendo los parámetros que definió para las pruebas!!!!

from string import ascii_lowercase
import random
random.seed(5)
def generate_random_string(length):
    return ''.join(random.choice(ascii_lowercase) for _ in range(length))

s1_t = generate_random_string(100000) #s1 base para test 1,2 y 3
s2_t1 = generate_random_string(5) #s2 test 1
s2_t2 = generate_random_string(3) #s2 test 2
s2_t3 = generate_random_string(10) #s2 test 3

# -----> cambie a XXX por su función!!!
assert XXX(s1_t, s2_t1) == 2, "Graaaaaave!"
assert XXX(s1_t, s2_t2) == 33, "Graaaaaave!"
assert XXX(s1_t, s2_t3) == 0, "Graaaaaave!"

s1_t4 = "a"*100000 #s1 para test 4
s2_t4 = "a" #s2 para test 4
assert XXX(s1_t4, s2_t4) == 100000, "Graaaaaave!"

# %% [markdown]
# ## Ejercicio 2 — Reconstrucción de Consultas
# ---

# %% [markdown]
# Un motor de búsqueda interno recibe consultas de usuarios como una sola cadena de texto
# sin espacios. Para procesarlas correctamente, el sistema debe determinar si la consulta
# puede reconstruirse concatenando palabras de su diccionario interno. Las palabras del
# diccionario pueden usarse más de una vez, y no es necesario usar todas.
#
# Dado un string `s1` y una lista de strings `words` (sin duplicados), implemente una
# función que retorne `True` si `s1` puede formarse concatenando en orden uno o más
# elementos de `words` (con posible repetición), o `False` en caso contrario.
#
# Deberá justificar la complejidad temporal y espacial de su solución.
#
#
#
# #### Ejemplo 1
# * s1 = "nomehaganesto"
# * words = ["mehaga", "n", "o", "x", "esto"]
# * "n" + "o" + "mehaga" + "n" + "esto" = "nomehaganesto" ✅ --> True
#
# #### Ejemplo 2
# * s1 = "catsandog"
# * words = ["cats", "dog", "sand", "and", "cat"]
# * No existe combinación válida que cubra "catsandog" exactamente --> False

# %%
'''
- Recuerde incluir typehints y justificación del análisis de complejidad temporal y espacial
- Si usa programación dinámica, describa qué significa cada subproblema, es decir, su clave:valor en memo o la celda de la tabla de programación dinámica.
- Puede borrar este comentario si lo considera necesario
'''

# su función aquí

# %%
# recuerde cambiar el XXX por el nombre de su función incluyendo los parámetros que definió para las pruebas!!!!

import random
random.seed(5)

# Test cases
test_cases = [
    ("leetcode", ["leet", "code"], True),
    ("applepenapple", ["apple", "pen"], True),
    ("catsandog", ["cats", "dog", "sand", "and", "cat"], False),
    ("aaaaaaaaaaaaaaaaaaaaaaaaaaa", ["a"], True),
    ("abaaabaaaaabaababaaaaaaaaaaaaaaaaaaaabababaababbabaaaaaababababaabaabaabababababaababaaaaabbbaaaab", ["a", "ab", "c", "b"], True),
    ("", ["a", "ab", "c", "b"], False)
]

# -----> cambie a XXX por su función!!!
for word, words, expected in test_cases:
    assert XXX(...) == expected, f"Graaaaaave! Test case: {word}, {words}"

# Otros test cases
test_cases = [("".join(random.choices("abc", k=100)), ["".join(random.choices("abc", k=random.randint(1, 5))) for _ in range(5)]) for _ in range(20)]
answers = [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False]

# -----> cambie a XXX por su función!!!
for i, (word, words) in enumerate(test_cases):
    assert XXX(...) == answers[i], f"Graaaaaave! Test case {i+1} falló!!!"
